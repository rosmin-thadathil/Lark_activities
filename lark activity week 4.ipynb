# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_excel('c:/Users/Rosmin/Downloads/Telco-Customer-Churn.xlsx')
# Out:
# C:\Users\Rosmin\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # churn count vs gender

# %%
sns.countplot(x='gender',hue='Churn',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# # count of female senior citizens

# %%
fsc=data.loc[(data["gender"]=="Female")&(data["SeniorCitizen"]==1)]
fsc
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female            1.0     Yes         No    71.0
# 50    8012-SOUDQ  Female            1.0      No         No    43.0
# 52    6575-SUVOI  Female            1.0     Yes         No    25.0
# 53    7495-OOKFY  Female            1.0     Yes         No     8.0
# 54    4667-QONEA  Female            1.0     Yes        Yes    60.0
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female            1.0     Yes         No    50.0
# 7008  1980-KXVPM  Female            1.0      No         No     3.0
# 7010  0723-DRCLG  Female            1.0     Yes         No     1.0
# 7023  1035-IPQPU  Female            1.0     Yes         No    63.0
# 7029  2235-DWLJU  Female            1.0      No         No     6.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %% [markdown]
# # tenure vs total charges

# %%
data[['tenure','TotalCharges']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # preferd by senior citizen

# %%
psc=data.loc[(data["SeniorCitizen"]==1)]
psc.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20  8779-QRDMV    Male            1.0      No         No     1.0           No
# 30  3841-NFECX  Female            1.0     Yes         No    71.0          Yes
# 31  4929-XIHVW    Male            1.0     Yes         No     2.0          Yes
# 34  3413-BMNZE    Male            1.0      No         No     1.0          Yes
# 50  8012-SOUDQ  Female            1.0      No         No    43.0          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 20  No phone service             DSL             No  ...              Yes
# 30               Yes     Fiber optic            Yes  ...              Yes
# 31                No     Fiber optic             No  ...              Yes
# 34                No             DSL             No  ...               No
# 50               Yes     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # findings on payment method

# %%
sns.countplot(data["PaymentMethod"],hue=data["gender"])
plt.xticks(rotation=30)
# Out:
# C:\Users\Rosmin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])
